# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("cleaned_mushroom_df.csv")

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  id cap-shape cap-surface cap-color bruises  \
# 0             0           0   1         x           s         n       t
# 1             1           1   2         x           s         y       t
# 2             2           2   3         b           s         w       t
# 3             3           3   4         x           y         w       t
# 4             4           4   5         x           s         g       f
#
#                 odor gill-attachment gill-spacing  ... stalk-color-below-ring  \
# 0  Certain Poisonous               f            c  ...                      w
# 1     Certain Edible               f            c  ...                      w
# 2     Certain Edible               f            c  ...                      w
# 3  Certain Poisonous               f            c  ...                      w
# 4                  n               f            w  ...                      w
#
#   veil-type veil-color ring-number ring-type spore-print-color  \
# 0         p          w           o         p                 k
# 1         p          w           o         p                 n
# 2         p          w           o         p                 n
# 3         p          w           o         p                 k
# 4         p          w           o         e                 n
#
#        population habitat class label
# 0               s       u     p     0
# 1  Certain Edible       g     e     1
# 2  Certain Edible       m     e     1
# 3               s       u     p     0
# 4  Certain Edible       g     e     1
#
# [5 rows x 27 columns]

# %%
y = df["class"]

X = df.drop(columns="class")
X = pd.get_dummies(X)

# %%
y.head()
# Out:
# 0    p
# 1    e
# 2    e
# 3    p
# 4    e
# Name: class, dtype: object

# %%
x.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  id cap-shape cap-surface cap-color bruises  \
# 0             0           0   1         x           s         n       t
# 1             1           1   2         x           s         y       t
# 2             2           2   3         b           s         w       t
# 3             3           3   4         x           y         w       t
# 4             4           4   5         x           s         g       f
#
#                 odor gill-attachment gill-spacing  ... stalk-color-above-ring  \
# 0  Certain Poisonous               f            c  ...                      w
# 1     Certain Edible               f            c  ...                      w
# 2     Certain Edible               f            c  ...                      w
# 3  Certain Poisonous               f            c  ...                      w
# 4                  n               f            w  ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color      population habitat label
# 0                 k               s       u     0
# 1                 n  Certain Edible       g     1
# 2                 n  Certain Edible       m     1
# 3                 k               s       u     0
# 4                 n  Certain Edible       g     1
#
# [5 rows x 26 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
model = LogisticRegression(random_state=1, max_iter=8500)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=8500, random_state=1)

# %%
y_prediction = model.predict(X_test)

# %%
confusion_matrix(y_test, y_prediction)
# Out:
# array([[1020,    0],
#        [   0, 1011]], dtype=int64)

# %%
print(classification_report(y_test, y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00      1020
#            p       1.00      1.00      1.00      1011
#
#     accuracy                           1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
